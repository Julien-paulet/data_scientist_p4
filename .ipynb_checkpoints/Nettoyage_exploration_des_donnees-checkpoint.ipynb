# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#Importons aussi notre fonction de recherche de description dans les metadatas :
from description import search_desc

# %% [markdown]
# # Import des données

# %%
data_2015 = pd.read_csv('2015-building-energy-benchmarking.csv')
data_2016 = pd.read_csv('2016-building-energy-benchmarking.csv')

# %% [markdown]
# # Nettoyage

# %%
data_2015.columns[~data_2015.columns.isin(data_2016.columns)]
# Out:
# Index(['Location', 'OtherFuelUse(kBtu)', 'GHGEmissions(MetricTonsCO2e)',
#        'GHGEmissionsIntensity(kgCO2e/ft2)', 'Comment', '2010 Census Tracts',
#        'Seattle Police Department Micro Community Policing Plan Areas',
#        'City Council Districts', 'SPD Beats', 'Zip Codes'],
#       dtype='object')

# %%
data_2016.columns[~data_2016.columns.isin(data_2015.columns)]
# Out:
# Index(['Address', 'City', 'State', 'ZipCode', 'Latitude', 'Longitude',
#        'Comments', 'TotalGHGEmissions', 'GHGEmissionsIntensity'],
#       dtype='object')

# %% [markdown]
# ## Traitement des colonnes différentes pour 2015 et 2016

# %%
# Tout d'abord les colonnes n'ayant pas le même nom mais représentant la même chose : 
data_2015 = data_2015.rename(columns = {'Zip Codes':'ZipCode', 
                                        'GHGEmissionsIntensity(kgCO2e/ft2)':'GHGEmissionsIntensity',
                                       'GHGEmissions(MetricTonsCO2e)':'TotalGHGEmissions',
                                       })

#Puis la colonne Location en 2015 qui contient en fait la latitude/longitude 
#Ainsi que l'adresse, mais nous n'en avons pas besoin puisque nous avons la latitude/longitude : 
data_2015['lat_lon'] = data_2015['Location'].str.rsplit(',').str[0:2]
data_2015['Latitude'] = data_2015['lat_lon'].str[0].str.split(':').str[1]
data_2015['Longitude'] = data_2015['lat_lon'].str[1].str.split(':').str[1]

data_2015 = data_2015.drop(columns=['lat_lon', 'Location'])

# %% [markdown]
# ## Concat pour avoir un seul jeu de données

# %%
data = pd.concat([data_2016, data_2015], sort=True, join='inner')

# %%
data.head()
# Out:
#      BuildingType ComplianceStatus  CouncilDistrictCode  DataYear DefaultData  \
# 0  NonResidential        Compliant                    7      2016       False
# 1  NonResidential        Compliant                    7      2016       False
# 2  NonResidential        Compliant                    7      2016       False
# 3  NonResidential        Compliant                    7      2016       False
# 4  NonResidential        Compliant                    7      2016       False
#
#    ENERGYSTARScore  Electricity(kBtu)  Electricity(kWh)  \
# 0             60.0          3946027.0      1.156514e+06
# 1             61.0          3242851.0      9.504252e+05
# 2             43.0         49526664.0      1.451544e+07
# 3             56.0          2768924.0      8.115253e+05
# 4             75.0          5368607.0      1.573449e+06
#
#    GHGEmissionsIntensity LargestPropertyUseType   ...     SourceEUI(kBtu/sf)  \
# 0                   2.83                  Hotel   ...             182.500000
# 1                   2.86                  Hotel   ...             176.100006
# 2                   2.19                  Hotel   ...             241.899994
# 3                   4.67                  Hotel   ...             216.199997
# 4                   2.88                  Hotel   ...             211.399994
#
#   SourceEUIWN(kBtu/sf) SteamUse(kBtu) TaxParcelIdentificationNumber  \
# 0           189.000000     2003882.00                    0659000030
# 1           179.399994           0.00                    0659000220
# 2           244.100006    21566554.00                    0659000475
# 3           224.000000     2214446.25                    0659000640
# 4           215.600006           0.00                    0659000970
#
#    ThirdLargestPropertyUseType  ThirdLargestPropertyUseTypeGFA  \
# 0                          NaN                             NaN
# 1                   Restaurant                          4622.0
# 2                          NaN                             NaN
# 3                          NaN                             NaN
# 4                Swimming Pool                             0.0
#
#   TotalGHGEmissions  YearBuilt  YearsENERGYSTARCertified  ZipCode
# 0            249.98       1927                       NaN  98101.0
# 1            295.86       1996                       NaN  98101.0
# 2           2089.28       1969                       NaN  98101.0
# 3            286.43       1926                       NaN  98101.0
# 4            505.01       1980                       NaN  98121.0
#
# [5 rows x 42 columns]

# %% [markdown]
# ## Gestion des doublons

# %%
search_desc('TaxParcelIdentificationNumber', 2015)
# Out:
# '\t\nProperty King County PIN'

# %%
doublon = data.groupby(['TaxParcelIdentificationNumber', 'Latitude', 'Longitude'])['DefaultData'].count()
doublon = doublon.reset_index()
doublon = doublon[doublon['DefaultData'] > 1]
doublon
# Out:
#      TaxParcelIdentificationNumber        Latitude         Longitude  \
# 10                      0002400002         47.6093          -122.334
# 43                      0164000222         47.7288          -122.349
# 111                     0467000420         47.6659          -122.385
# 125                     0586400000         47.6171          -122.351
# 329                     0925049346         47.6625          -122.299
# 336                     0925049426         47.6625          -122.299
# 356                     0939000300         47.6043          -122.334
# 624                     1333100000         47.5614          -122.385
# 785                      164000222   '47.72873257'   '-122.34910229'
# 960                     1868903240         47.6748          -122.293
# 961                     1868903240   '47.67465943'    '-122.2928258'
# 1018                    1926049347   '47.72636707'    '-122.3491289'
# 1149                    1972206650   '47.64934199'    '-122.3558772'
# 1390                    1978200280         47.6105          -122.328
# 1391                    1978200280    '47.6104434'    '-122.3284162'
# 1524                    1985200003         47.6221          -122.354
# 1525                    1985200003   '47.62124083'    '-122.3534322'
# 1538                    1985200305         47.6221          -122.354
# 1539                    1985200305   '47.62189039'    '-122.3502752'
# 1580                    1988200440   '47.62393635'      '-122.35193'
# 1583                    1988200700   '47.62388082'    '-122.3499699'
# 1744                    2025049007         47.6413          -122.316
# 1745                    2025049007   '47.64171214'    '-122.3173859'
# 1805                    2123700250   '47.52427301'    '-122.2714398'
# 1828                    2141290000          47.611          -122.332
# 2002                       2400002   '47.60831575'   '-122.33544853'
# 2003                       2400003   '47.60816177'   '-122.33434527'
# 2038                    2434900010    '47.7007902'    '-122.3272232'
# 2253                    2767604965   '47.67057565'    '-122.3866853'
# 2338                    2768301991   '47.66431539'    '-122.3730423'
# ...                            ...             ...               ...
# 4784                    7015350000   '47.62496806'     '-122.359705'
# 4932                    7378600265   '47.53830025'    '-122.2840532'
# 5025                    7579200260         47.5596          -122.385
# 5026                    7579200260   '47.55989777'    '-122.3846207'
# 5071                    7660600235   '47.58810829'    '-122.3181503'
# 5098                    7666200070   '47.65676796'    '-122.3704009'
# 5163                    7666202485         47.6055          -122.341
# 5164                    7666202485   '47.60455844'     '-122.339397'
# 5203                    7666203240         47.5829          -122.324
# 5204                    7666203240    '47.5829049'    '-122.3228994'
# 5296                    7666204800   '47.59343565'    '-122.3266241'
# 5299                    7666204876         47.5954          -122.332
# 5300                    7666204876   '47.59435403'    '-122.3301787'
# 5315                    7666205660          47.572          -122.328
# 5316                    7666205660   '47.57125847'     '-122.331498'
# 5373                    7666206865   '47.59648755'    '-122.3336611'
# 5606                    7933000005   '47.66147138'    '-122.2862292'
# 5640                    7954000005   '47.57961979'    '-122.2948436'
# 5670                    7985400265         47.5342          -122.366
# 5671                    7985400265   '47.53409853'    '-122.3661589'
# 5832                    8590900220   '47.60387131'    '-122.3226998'
# 5876                    8592900285   '47.59524558'    '-122.3229473'
# 5892                    8632880000    '47.7024765'   '-122.32480621'
# 5916                    8681450000         47.6239          -122.358
# 5917                    8681450000   '47.62392426'   '-122.35764313'
# 6207                    8900000555         47.6502          -122.362
# 6208                    8900000555   '47.64835098'    '-122.3616099'
# 6298                     925049346   '47.66375728'    '-122.3002168'
# 6305                     925049426   '47.66384364'   '-122.29717129'
# 6401                     939000300   '47.60387657'   '-122.33374327'
#
#       DefaultData
# 10              2
# 43              2
# 111             2
# 125             2
# 329             5
# 336             2
# 356             3
# 624             2
# 785             3
# 960             2
# 961             2
# 1018            2
# 1149            2
# 1390            2
# 1391            2
# 1524            3
# 1525            3
# 1538            2
# 1539            2
# 1580            2
# 1583            2
# 1744            2
# 1745            3
# 1805            2
# 1828            2
# 2002            5
# 2003            2
# 2038            2
# 2253            2
# 2338            2
# ...           ...
# 4784            2
# 4932            2
# 5025            2
# 5026            2
# 5071            2
# 5098            2
# 5163            2
# 5164            2
# 5203            4
# 5204            4
# 5296            2
# 5299            2
# 5300            2
# 5315            2
# 5316            2
# 5373            2
# 5606            2
# 5640            3
# 5670            2
# 5671            2
# 5832            2
# 5876            2
# 5892            2
# 5916            2
# 5917            2
# 6207            2
# 6208            2
# 6298            5
# 6305            2
# 6401            3
#
# [96 rows x 4 columns]

# %% [markdown]
# 129 buildings sont donc compté plusieurs fois dans le jeu de données

# %%
data.shape
# Out:
# (6716, 42)

# %%
for col in data.columns:
    print(col)
# Out:
# BuildingType
# ComplianceStatus
# CouncilDistrictCode
# DataYear
# DefaultData
# ENERGYSTARScore
# Electricity(kBtu)
# Electricity(kWh)
# GHGEmissionsIntensity
# LargestPropertyUseType
# LargestPropertyUseTypeGFA
# Latitude
# ListOfAllPropertyUseTypes
# Longitude
# NaturalGas(kBtu)
# NaturalGas(therms)
# Neighborhood
# NumberofBuildings
# NumberofFloors
# OSEBuildingID
# Outlier
# PrimaryPropertyType
# PropertyGFABuilding(s)
# PropertyGFAParking
# PropertyGFATotal
# PropertyName
# SecondLargestPropertyUseType
# SecondLargestPropertyUseTypeGFA
# SiteEUI(kBtu/sf)
# SiteEUIWN(kBtu/sf)
# SiteEnergyUse(kBtu)
# SiteEnergyUseWN(kBtu)
# SourceEUI(kBtu/sf)
# SourceEUIWN(kBtu/sf)
# SteamUse(kBtu)
# TaxParcelIdentificationNumber
# ThirdLargestPropertyUseType
# ThirdLargestPropertyUseTypeGFA
# TotalGHGEmissions
# YearBuilt
# YearsENERGYSTARCertified
# ZipCode

# %%
search_desc("SiteEnergyUseWN(kBtu)", 2016)
# Out:
# 'The annual amount of energy consumed by the property from all sources of energy, adjusted to what the property would have consumed during 30-year average weather conditions.'

# %%
search_desc("TotalGHGEmissions", 2016)
# Out:
# "The total amount of greenhouse gas emissions, including carbon dioxide, methane, and nitrous oxide gases released into the atmosphere as a result of energy consumption at the property, measured in metric tons of carbon dioxide equivalent. This calculation uses a GHG emissions factor from Seattle CIty Light's portfolio of generating resources. This uses Seattle City Light's 2015 emissions factor of 52.44 lbs CO2e/MWh until the 2016 factor is available. Enwave steam factor = 170.17 lbs CO2e/MMBtu. Gas factor sourced from EPA Portfolio Manager = 53.11 kg CO2e/MBtu. "

# %% [markdown]
# On a désormais nos deux variables cible : SiteEnergyUseWN(kBtu) et TotalGHGEmissions

# %%
# Col useless : 
# SecondLargestPropertyUseType, SecondLargestPropertyUseTypeGFA, OSEBuildingID, ListOfAllPropertyUseTypes,
# LargestPropertyUseTypeGFA, LargestPropertyUseType, Electricity(kBtu),

# %%
#Variable cible 1 : 
#data_2016["Electricity(kWh)"] ?? Ou bien data_2016["SiteEnergyUseWN(kBtu)"], NaturalGas(kBtu) ? all ?

#Variable cible 2 : 
#data_2016["TotalGHGEmissions"] ??

# %%
from functions import isnan
isnan(data)
# Out:
# La colonne 'DefaultData' comporte 1 / 6716 valeur(s) manquante(s)
# Ce qui représente 0.01488981536628946%
# La colonne 'ENERGYSTARScore' comporte 1623 / 6716 valeur(s) manquante(s)
# Ce qui représente 24.166170339487792%
# La colonne 'Electricity(kBtu)' comporte 19 / 6716 valeur(s) manquante(s)
# Ce qui représente 0.2829064919594997%
# La colonne 'Electricity(kWh)' comporte 19 / 6716 valeur(s) manquante(s)
# Ce qui représente 0.2829064919594997%
# La colonne 'GHGEmissionsIntensity' comporte 19 / 6716 valeur(s) manquante(s)
# Ce qui représente 0.2829064919594997%
# La colonne 'LargestPropertyUseType' comporte 156 / 6716 valeur(s) manquante(s)
# Ce qui représente 2.3228111971411556%
# La colonne 'LargestPropertyUseTypeGFA' comporte 156 / 6716 valeur(s) manquante(s)
# Ce qui représente 2.3228111971411556%
# La colonne 'ListOfAllPropertyUseTypes' comporte 136 / 6716 valeur(s) manquante(s)
# Ce qui représente 2.0250148898153664%
# La colonne 'NaturalGas(kBtu)' comporte 19 / 6716 valeur(s) manquante(s)
# Ce qui représente 0.2829064919594997%
# La colonne 'NaturalGas(therms)' comporte 19 / 6716 valeur(s) manquante(s)
# Ce qui représente 0.2829064919594997%
# La colonne 'NumberofBuildings' comporte 8 / 6716 valeur(s) manquante(s)
# Ce qui représente 0.11911852293031568%
# La colonne 'NumberofFloors' comporte 8 / 6716 valeur(s) manquante(s)
# Ce qui représente 0.11911852293031568%
# La colonne 'Outlier' comporte 6600 / 6716 valeur(s) manquante(s)
# Ce qui représente 98.27278141751043%
# La colonne 'SecondLargestPropertyUseType' comporte 3478 / 6716 valeur(s) manquante(s)
# Ce qui représente 51.78677784395474%
# La colonne 'SecondLargestPropertyUseTypeGFA' comporte 3478 / 6716 valeur(s) manquante(s)
# Ce qui représente 51.78677784395474%
# La colonne 'SiteEUI(kBtu/sf)' comporte 17 / 6716 valeur(s) manquante(s)
# Ce qui représente 0.2531268612269208%
# La colonne 'SiteEUIWN(kBtu/sf)' comporte 16 / 6716 valeur(s) manquante(s)
# Ce qui représente 0.23823704586063135%
# La colonne 'SiteEnergyUse(kBtu)' comporte 15 / 6716 valeur(s) manquante(s)
# Ce qui représente 0.22334723049434188%
# La colonne 'SiteEnergyUseWN(kBtu)' comporte 16 / 6716 valeur(s) manquante(s)
# Ce qui représente 0.23823704586063135%
# La colonne 'SourceEUI(kBtu/sf)' comporte 19 / 6716 valeur(s) manquante(s)
# Ce qui représente 0.2829064919594997%
# La colonne 'SourceEUIWN(kBtu/sf)' comporte 19 / 6716 valeur(s) manquante(s)
# Ce qui représente 0.2829064919594997%
# La colonne 'SteamUse(kBtu)' comporte 19 / 6716 valeur(s) manquante(s)
# Ce qui représente 0.2829064919594997%
# La colonne 'TaxParcelIdentificationNumber' comporte 2 / 6716 valeur(s) manquante(s)
# Ce qui représente 0.02977963073257892%
# La colonne 'ThirdLargestPropertyUseType' comporte 5560 / 6716 valeur(s) manquante(s)
# Ce qui représente 82.7873734365694%
# La colonne 'ThirdLargestPropertyUseTypeGFA' comporte 5560 / 6716 valeur(s) manquante(s)
# Ce qui représente 82.7873734365694%
# La colonne 'TotalGHGEmissions' comporte 19 / 6716 valeur(s) manquante(s)
# Ce qui représente 0.2829064919594997%
# La colonne 'YearsENERGYSTARCertified' comporte 6487 / 6716 valeur(s) manquante(s)
# Ce qui représente 96.59023228111971%
# La colonne 'ZipCode' comporte 16 / 6716 valeur(s) manquante(s)
# Ce qui représente 0.23823704586063135%
# 28 colonnes au total possèdent des valeurs manquantes
# 1196.5714285714287 / 6716 valeurs sont manquantes en moyenne dans chaque colonne

# %% [markdown]
# ## Gestion des valeurs manquantes

# %% [markdown]
# ### Plus de 50% des valeurs manquantes

# %%
# On utilise une boucle pour récupérer le taux de valeurs manquantes
taille = len(data)
nulle = []
for i in data.columns:
    nbr = len(data[i])-len(data[i].dropna())
    taux = nbr/taille*100
    col = data[i]
    if taux >= 50:
        del data[i] #On enlève ensuite les colonnes possédant + de 50% de valeurs manquantes

data.shape
# Out:
# (6716, 36)

# %% [markdown]
# 6 colonnes ont été retirées

# %% [markdown]
# ### Moins de 50% de valeurs manquantes

# %% [markdown]
# ## Apperçu des données

# %%
data.describe()
# Out:
#        CouncilDistrictCode    DataYear  ENERGYSTARScore  Electricity(kBtu)  \
# count          6716.000000  6716.00000      5093.000000       6.697000e+03
# mean              4.445057  2015.50268        67.906342       3.591058e+06
# std               2.123749     0.50003        27.012124       1.248728e+07
# min               1.000000  2015.00000         1.000000      -1.154170e+05
# 25%               3.000000  2015.00000        52.000000       6.372730e+05
# 50%               4.000000  2016.00000        75.000000       1.167735e+06
# 75%               7.000000  2016.00000        90.000000       2.797320e+06
# max               7.000000  2016.00000       100.000000       6.570744e+08
#
#        Electricity(kWh)  GHGEmissionsIntensity  LargestPropertyUseTypeGFA  \
# count      6.697000e+03            6697.000000               6.560000e+03
# mean       1.052458e+06               1.081154               7.707936e+04
# std        3.659769e+06               1.734763               1.681617e+05
# min       -3.382680e+04              -0.020000               5.656000e+03
# 25%        1.867660e+05               0.160000               2.501600e+04
# 50%        3.422434e+05               0.540000               3.953000e+04
# 75%        8.198140e+05               1.280000               7.417800e+04
# max        1.925775e+08              34.090000               9.320156e+06
#
#        NaturalGas(kBtu)  NaturalGas(therms)  NumberofBuildings      ...       \
# count      6.697000e+03        6.697000e+03        6708.000000      ...
# mean       1.311223e+06        1.311223e+04           1.071407      ...
# std        5.685627e+06        5.685626e+04           1.593505      ...
# min        0.000000e+00        0.000000e+00           0.000000      ...
# 25%        0.000000e+00        0.000000e+00           1.000000      ...
# 50%        3.051000e+05        3.051000e+03           1.000000      ...
# 75%        1.149639e+06        1.149639e+04           1.000000      ...
# max        2.979090e+08        2.979090e+06         111.000000      ...
#
#        SiteEUI(kBtu/sf)  SiteEUIWN(kBtu/sf)  SiteEnergyUse(kBtu)  \
# count       6699.000000         6700.000000         6.701000e+03
# mean          54.182341           57.308522         5.194673e+06
# std           55.101657           56.390651         1.813648e+07
# min            0.000000            0.000000         0.000000e+00
# 25%           27.600000           29.600000         9.200689e+05
# 50%           38.000000           40.900000         1.791071e+06
# 75%           60.200000           64.925001         4.135280e+06
# max          834.400024          834.400024         8.739237e+08
#
#        SiteEnergyUseWN(kBtu)  SourceEUI(kBtu/sf)  SourceEUIWN(kBtu/sf)  \
# count           6.700000e+03         6697.000000           6697.000000
# mean            5.240110e+06          133.510303            138.356802
# std             1.500896e+07          135.677195            135.302508
# min             0.000000e+00           -2.000000             -2.100000
# 25%             9.818029e+05           74.000000             79.199997
# 50%             1.926136e+06           95.600000            102.099998
# 75%             4.377974e+06          143.900000            149.800000
# max             4.716139e+08         2620.000000           2620.000000
#
#        SteamUse(kBtu)  TotalGHGEmissions    YearBuilt       ZipCode
# count    6.697000e+03        6697.000000  6716.000000   6700.000000
# mean     2.625076e+05         114.935638  1968.101549  58570.218060
# std      3.704221e+06         478.876573    33.020391  39670.096871
# min      0.000000e+00          -0.800000  1900.000000  17916.000000
# 25%      0.000000e+00           9.450000  1948.000000  18390.000000
# 50%      0.000000e+00          33.180000  1974.000000  98061.500000
# 75%      0.000000e+00          91.530000  1996.000000  98115.000000
# max      1.349435e+08       16870.980000  2015.000000  98272.000000
#
# [8 rows x 25 columns]

# %% [markdown]
# ## Division du dataset en deux parties

# %% [markdown]
# Divisons le dataset en deux parties, une partie quanti et une quali, cette division est effectuées sur les variables qualitatives et celles quantitatives

# %%
data_quanti = 
data_quali =

# %% [markdown]
# ## Traitement des valeurs abberantes

# %% [markdown]
# ### Valeurs minimales

# %%
for col in data.columns:
    data[col] = data[data[col] >= 0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-72-ed05482ffe78> in <module>
#       1 for col in data.columns:
# ----> 2     data[col] = data[data[col] >= 0]
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops.py in wrapper(self, other, axis)
#    1281
#    1282             with np.errstate(all='ignore'):
# -> 1283                 res = na_op(values, other)
#    1284             if is_scalar(res):
#    1285                 raise TypeError('Could not compare {typ} type with Series'
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#    1141
#    1142         elif is_object_dtype(x.dtype):
# -> 1143             result = _comp_method_OBJECT_ARRAY(op, x, y)
#    1144
#    1145         elif is_datetimelike_v_numeric(x, y):
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops.py in _comp_method_OBJECT_ARRAY(op, x, y)
#    1120         result = libops.vec_compare(x, y, op)
#    1121     else:
# -> 1122         result = libops.scalar_compare(x, y, op)
#    1123     return result
#    1124
#
# pandas\_libs\ops.pyx in pandas._libs.ops.scalar_compare()
#
# TypeError: '>=' not supported between instances of 'str' and 'int'

# %% [markdown]
# # Analyses

# %% [markdown]
# ## Univariées

# %% [markdown]
# ## Bivariées

# %% [markdown]
# ### Matrice de corrélation

# %%
pearson_corr = round(data_2016.corr(), 2)

plt.figure(figsize=(20,20))
sns.heatmap(pearson_corr, 
            xticklabels=pearson_corr.columns,
            yticklabels=pearson_corr.columns,
            cmap='RdBu_r',
            annot=True,
            linewidth=0.5)
plt.show()
